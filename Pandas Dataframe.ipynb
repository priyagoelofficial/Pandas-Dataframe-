# %% [markdown]
# #### Q1. Creating a DataFrame ___Create a Pandas DataFrame using a Python dictionary with the following columns: Product, Region, Sales, Quantity

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Product':['Laptop','Fridge','LED','Speaker'],
    'Region':['North','South','East','West'],
    'Sales': [2000,5000,8500,6104],
    'Quantity':[54,6,89,32]
}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    Product Region  Sales  Quantity
# 0   Laptop  North   2000        54
# 1   Fridge  South   5000         6
# 2      LED   East   8500        89
# 3  Speaker   West   6104        32

# %% [markdown]
# ####

# %% [markdown]
# #### Data Load

# %%
df2=pd.read_csv(r"C:\Users\Priya Goel\Downloads\Retail_dataset.csv")

# %% [markdown]
# #### Q2. Data Inspection. Perform the following inspection tasks:
#
# ##### 1. Display the first 5 rows of the dataset.
#
# ##### 2. Display the last 5 rows.
#
# ##### 3. Show the structure of the dataset using info().
#
# ##### 4. Display the shape of the dataset

# %%
df2.head()
# Out:
#    Order_ID Customer   Product Region  Sales  Quantity
# 0      1001    Sneha    Laptop   West   1056         2
# 1      1002     Neha    Tablet  South    904         7
# 2      1003    Meera    Laptop  South   1597         5
# 3      1004    Rohan  Keyboard  North    777         8
# 4      1005    Priya     Phone  South   2028         4

# %%
df2.tail()
# Out:
#     Order_ID Customer   Product Region  Sales  Quantity
# 85      1086    Pooja    Laptop   East   1330         2
# 86      1087    Anita  Keyboard   West    741         3
# 87      1088    Karan   Monitor   East    875         2
# 88      1089      Raj    Tablet  North   2213         5
# 89      1090    Priya    Laptop  South   1270         2

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Order_ID  90 non-null     int64
#  1   Customer  90 non-null     str
#  2   Product   90 non-null     str
#  3   Region    90 non-null     str
#  4   Sales     90 non-null     int64
#  5   Quantity  90 non-null     int64
# dtypes: int64(3), str(3)
# memory usage: 4.3 KB

# %%
df2.shape
# Out:
# (90, 6)

# %% [markdown]
# #### Q3. Column Selection:- Select and display only the following columns:
#
# #### Product
#
# #### Region
#
# #### Sales

# %%
slct=df2[['Product','Region','Sales']]

# %%
slct.head()
# Out:
#     Product Region  Sales
# 0    Laptop   West   1056
# 1    Tablet  South    904
# 2    Laptop  South   1597
# 3  Keyboard  North    777
# 4     Phone  South   2028

# %% [markdown]
# ##### Q4. Indexing using .loc :- Using .loc, perform the following:
# ##### 1. Display the row with index 10.
# ##### 2. Display the Sales value of the row with index 20

# %%
indx=slct.loc[:10]
indx  # it will print output
#print(slct.loc[:10]) # it will also print same ooutput
# Out:
#      Product Region  Sales
# 0     Laptop   West   1056
# 1     Tablet  South    904
# 2     Laptop  South   1597
# 3   Keyboard  North    777
# 4      Phone  South   2028
# 5     Tablet   West    638
# 6    Monitor  South   1004
# 7    Monitor   East   1269
# 8      Phone  North    827
# 9      Phone   West   1998
# 10   Monitor  North   1693

# %%
indx2=slct.loc[:20,['Sales']]
indx2
# Out:
#     Sales
# 0    1056
# 1     904
# 2    1597
# 3     777
# 4    2028
# 5     638
# 6    1004
# 7    1269
# 8     827
# 9    1998
# 10   1693
# 11   1022
# 12   1191
# 13   2078
# 14    813
# 15    796
# 16   2015
# 17   1637
# 18    748
# 19   1503
# 20   1021

# %% [markdown]
# #### Q5. Indexing using .iloc :- Using .iloc, display:
#
# #### 1. The first 6 rows and first 4 columns.
#
# #### 2. The Sales value from the 3rd row.

# %%
iloc_q=df2.iloc[:7,:4]
iloc_q
# Out:
#    Order_ID Customer   Product Region
# 0      1001    Sneha    Laptop   West
# 1      1002     Neha    Tablet  South
# 2      1003    Meera    Laptop  South
# 3      1004    Rohan  Keyboard  North
# 4      1005    Priya     Phone  South
# 5      1006    Rahul    Tablet   West
# 6      1007     Amit   Monitor  South

# %%
iloc_q2=df2.iloc[2,4]
iloc_q2
# Out:
# np.int64(1597)

# %% [markdown]
# #### Q6. Row Slicing :- Display:
# #### 1. The first 10 rows of the dataset.
# #### 2. Rows 15 to 25.

# %%
slcing=df2.loc[:10]
slcing
# Out:
#     Order_ID Customer   Product Region  Sales  Quantity
# 0       1001    Sneha    Laptop   West   1056         2
# 1       1002     Neha    Tablet  South    904         7
# 2       1003    Meera    Laptop  South   1597         5
# 3       1004    Rohan  Keyboard  North    777         8
# 4       1005    Priya     Phone  South   2028         4
# 5       1006    Rahul    Tablet   West    638         2
# 6       1007     Amit   Monitor  South   1004         7
# 7       1008    Sneha   Monitor   East   1269         8
# 8       1009    Priya     Phone  North    827         8
# 9       1010     Amit     Phone   West   1998         4
# 10      1011      Raj   Monitor  North   1693         6

# %%
slcing2=df2.loc[15:25]
slcing2
# Out:
#     Order_ID Customer  Product Region  Sales  Quantity
# 15      1016    Karan  Monitor   West    796         3
# 16      1017     Neha   Laptop   East   2015         2
# 17      1018    Anita    Phone  North   1637         3
# 18      1019     Amit    Phone   East    748         7
# 19      1020     Neha   Laptop   West   1503         6
# 20      1021    Priya   Laptop  North   1021         4
# 21      1022      Raj   Tablet  South    886         7
# 22      1023    Rahul   Laptop  South   2267         3
# 23      1024    Karan  Monitor   East    814         7
# 24      1025    Meera  Monitor   West   1926         6
# 25      1026    Anita   Tablet   East    839         5

# %% [markdown]
# #### Q7. Filtering Data :- Filter the dataset to display:
# #### 1. Rows where Region = "East".
# #### 2. Rows where Sales > 1500.

# %%
cndtn_filter=df2.loc[df2['Region']=='East']
cndtn_filter
# Out:
#     Order_ID Customer   Product Region  Sales  Quantity
# 7       1008    Sneha   Monitor   East   1269         8
# 11      1012    Rahul    Laptop   East   1022         5
# 16      1017     Neha    Laptop   East   2015         2
# 18      1019     Amit     Phone   East    748         7
# 23      1024    Karan   Monitor   East    814         7
# 25      1026    Anita    Tablet   East    839         5
# 31      1032     Amit    Laptop   East   2226         6
# 34      1035     Amit    Tablet   East   2104         3
# 35      1036    Rohan     Phone   East   2136         8
# 36      1037      Raj     Phone   East   1650         4
# 37      1038     Amit   Monitor   East   1567         8
# 38      1039    Meera  Keyboard   East   2455         3
# 44      1045    Priya     Phone   East   1875         4
# 47      1048    Rohan   Monitor   East   1103         2
# 52      1053    Rahul    Laptop   East   2276         1
# 53      1054      Raj   Monitor   East   1420         2
# ...

# %%
cndtn_filter2=df2.loc[df2['Sales']>1500]
cndtn_filter2
# Out:
#     Order_ID Customer   Product Region  Sales  Quantity
# 2       1003    Meera    Laptop  South   1597         5
# 4       1005    Priya     Phone  South   2028         4
# 9       1010     Amit     Phone   West   1998         4
# 10      1011      Raj   Monitor  North   1693         6
# 13      1014    Rohan     Phone  South   2078         3
# 16      1017     Neha    Laptop   East   2015         2
# 17      1018    Anita     Phone  North   1637         3
# 19      1020     Neha    Laptop   West   1503         6
# 22      1023    Rahul    Laptop  South   2267         3
# 24      1025    Meera   Monitor   West   1926         6
# 26      1027    Vikas    Laptop  North   1864         8
# 27      1028    Vikas    Laptop  North   1551         3
# 29      1030    Rohan   Monitor   West   1932         5
# 31      1032     Amit    Laptop   East   2226         6
# 34      1035     Amit    Tablet   East   2104         3
# 35      1036    Rohan     Phone   East   2136         8
# ...

# %% [markdown]
# #### Q8. Multiple Condition Filtering:- Display rows where:
# #### 1. Region is West
# #### 2. Sales is greater than 1200

# %%
mul_cndt_fltr=df2.loc[df2['Region']=='West']
mul_cndt_fltr
# Out:
#     Order_ID Customer   Product Region  Sales  Quantity
# 0       1001    Sneha    Laptop   West   1056         2
# 5       1006    Rahul    Tablet   West    638         2
# 9       1010     Amit     Phone   West   1998         4
# 14      1015    Sneha    Laptop   West    813         6
# 15      1016    Karan   Monitor   West    796         3
# 19      1020     Neha    Laptop   West   1503         6
# 24      1025    Meera   Monitor   West   1926         6
# 29      1030    Rohan   Monitor   West   1932         5
# 41      1042    Sneha  Keyboard   West   1114         1
# 42      1043    Meera  Keyboard   West   1515         6
# 43      1044    Vikas    Laptop   West   2248         5
# 49      1050    Karan   Monitor   West   2034         7
# 50      1051    Rahul    Tablet   West    717         4
# 55      1056    Rahul    Laptop   West   1481         1
# 58      1059    Karan    Tablet   West   2404         6
# 59      1060    Karan    Tablet   West   1651         2
# ...

# %%
mul_cndt_fltr2=df2.loc[df2['Sales']>1200]
mul_cndt_fltr2
# Out:
#     Order_ID Customer   Product Region  Sales  Quantity
# 2       1003    Meera    Laptop  South   1597         5
# 4       1005    Priya     Phone  South   2028         4
# 7       1008    Sneha   Monitor   East   1269         8
# 9       1010     Amit     Phone   West   1998         4
# 10      1011      Raj   Monitor  North   1693         6
# 13      1014    Rohan     Phone  South   2078         3
# 16      1017     Neha    Laptop   East   2015         2
# 17      1018    Anita     Phone  North   1637         3
# 19      1020     Neha    Laptop   West   1503         6
# 22      1023    Rahul    Laptop  South   2267         3
# 24      1025    Meera   Monitor   West   1926         6
# 26      1027    Vikas    Laptop  North   1864         8
# 27      1028    Vikas    Laptop  North   1551         3
# 28      1029    Pooja   Monitor  North   1370         7
# 29      1030    Rohan   Monitor   West   1932         5
# 31      1032     Amit    Laptop   East   2226         6
# ...

# %% [markdown]
# #### Q9. Descriptive Statistics :- Generate summary statistics using:
#
# #### describe()
#
# #### From the result identify:
#
# #### 1. Mean sales value
#
# #### 2. Maximum quantity sold
#
# #### 3. Minimum sales value

# %%
df2.describe()
# Out:
#           Order_ID        Sales   Quantity
# count    90.000000    90.000000  90.000000
# mean   1045.500000  1406.888889   4.700000
# std      26.124701   531.748302   2.179836
# min    1001.000000   515.000000   1.000000
# 25%    1023.250000   890.500000   3.000000
# 50%    1045.500000  1402.000000   5.000000
# 75%    1067.750000  1857.250000   7.000000
# max    1090.000000  2455.000000   8.000000

# %%
round(df2.describe().loc["mean", "Sales"],2)
# Out:
# np.float64(1406.89)

# %%
df2.describe().loc["max", "Quantity"]
# Out:
# np.float64(8.0)

# %%
df2.describe().loc["min", "Sales"]
# Out:
# np.float64(515.0)

# %% [markdown]
# #### Q10. Aggregation Analysis :- Using the Sales column, calculate:
#
# ##### 1. Total sales
#
# ##### 2. Average sales
#
# ##### 3. Maximum sales
#
# ##### 4. Minimum sales

# %%
tot_sale=np.sum(df2['Sales'])
print(tot_sale)
# Out:
# 126620

# %%
avg_sale=np.average(df2['Sales'])
print(avg_sale)
# Out:
# 1406.888888888889

# %%
max_sale=np.max(df2['Sales'])
print(max_sale)
# Out:
# 2455

# %%
min_sale=np.min(df2['Sales'])
print(min_sale)
# Out:
# 515
